# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from gen_eco_networks.models import NicheModel
from gen_eco_networks.utils import draw_network

SEED = 30

# instantiate the model
model = NicheModel(n_species=20, connectance=0.15, seed=SEED)

# generate the web using the niche model
web, _ = model.generate()

# visualize the generated web
draw_network(web, seed=SEED)
# Out:
# 0.2357988048125328 0.04461302006261461 0.050356888050454414
# 0.5926027569547103 0.5329683995811629 0.28453408379845746
# 0.3264548562025841 0.1349550114680214 0.015840966150000097
# 0.5916026939433029 0.3932779337937342 0.06867453271568161
# 0.90231831901175 0.4772376382610561 0.17278716311405018
# 0.7672737137010591 0.6033681159775395 0.2553656036146394
# 0.5068844864676446 0.20756896802168465 0.30476941779442956
# 0.5975447691865604 0.5772584678000122 0.024842627656293824
# 0.4343991361410571 0.39311797928331244 0.023453386538590904
# 0.928873170958703 0.3312102851907327 0.1006815436903605
# 0.18305881024391646 0.09644677164776634 0.0349497019476043
# 0.29446372941213617 0.09424966408293665 0.04601182217418089
# 0.11310850829849295 0.11129005375974337 0.007685668030564239
# 0.17524295096234066 0.16277901483741586 0.09260699418928392
# 0.6325989214471106 0.27383729303130444 0.24227641432519295
# 0.16232622877178504 0.08633501915235849 0.1189590710808978
# 0.9416052016622874 0.8682036074369488 0.46838154484447825
# 0.3911634690396635 0.1956332795122695 0.080297203804216
# 0.17379539798782362 0.037401802605090614 0.03772281131563578
# 0.6391233902237997 0.3106065860837875 0.07060269819163219
# [] [15]
# > /Users/vivian/code/gen_eco_networks/src/gen_eco_networks/models/niche.py(28)generate()
#      26     Attributes
#      27     ----------
# ---> 28     niche_values : dict[int, float]
#      29         Maps species ID to its niche value n_i in [0, 1].
#      30     range_values : dict[int, float]
#
# 0.33247543500154075 0.3321897660293558 0.16350747438232097
# [] []

# %%
# save the generated web to a gml file
model.save(web, "../example_networks/niche_model")

# save the generated web as node, edge, and attribute files
model.save(web, "../example_networks/niche_model", gml=False)

# read the web from files
read_web = model.read("../example_networks/niche_model", gml=True)

# visualize the web
draw_network(read_web, seed=SEED)

# %%
from gen_eco_networks.models import SBM
from gen_eco_networks.utils import draw_network

# instantiate the model
model = SBM(
    n_species=20,
    n_blocks=3,
    n_binary_attributes=1,
    n_numeric_attributes=2,
    reciprocal_proportion=0.1,
    seed=SEED,
)

# generate the web using the SBM
web, _ = model.generate()

# visualize the generated web
draw_network(web)

# save the generated web to example_networks/SBM/
model.save(web, "../example_networks/sbm")
model.save(web, "../example_networks/sbm", gml=False)

# %%
# generate and visualize train/test splits of the web
train_subgraph, test_subgraph = model.train_test_split(web, test_size=0.2)
draw_network(train_subgraph)
draw_network(test_subgraph)

# %%
from gen_eco_networks.models import RGG
from gen_eco_networks.utils import draw_network

# instantiate the model
model = RGG(
    n_species=20,
    radius=1.0,
    assortative=True,
    n_binary_attributes=2,
    n_numeric_attributes=4,
    seed=SEED,
)

# generate the web using RGG
web, _ = model.generate()

# visualize the generated web
draw_network(web)

# save the generated web to example_networks/rgg/
model.save(web, "../example_networks/rgg")
model.save(web, "../example_networks/rgg", gml=False)

# %%
from gen_eco_networks.models import PNM
from gen_eco_networks.utils import draw_network

# instantiate the model
model = PNM(
    n_species=20,
    connectance=0.15,
    rho=0.9,
    n_binary_attributes=2,
    n_numeric_attributes=4,
    seed=SEED,
)

# generate the web using PNM
web, _ = model.generate()

# visualize the generated web
draw_network(web)

# save the generated web to example_networks/rgg/
model.save(web, "../example_networks/pnm")
model.save(web, "../example_networks/pnm", gml=False)
